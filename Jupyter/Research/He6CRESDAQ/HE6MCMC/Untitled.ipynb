# %%
from astropy.table import QTable
import numpy as np
import matplotlib.pyplot as plt
import corner
import seaborn as sns
import pandas as pd

# %%
eid10 = pd.read_csv('./eid1/eid1_0.csv')
eid11 = pd.read_csv('./eid1/eid1_1.csv')
eid12 = pd.read_csv('./eid1/eid1_2.csv')
eid13 = pd.read_csv('./eid1/eid1_3.csv')
eid14 = pd.read_csv('./eid1/eid1_4.csv')
eid15 = pd.read_csv('./eid1/eid1_5.csv')
eid16 = pd.read_csv('./eid1/eid1_6.csv')
eid17 = pd.read_csv('./eid1/eid1_7.csv')
eid18 = pd.read_csv('./eid1/eid1_8.csv')
eid19 = pd.read_csv('./eid1/eid1_9.csv')

# %%
sns.scatterplot(data =eid10, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
sns.scatterplot(data =eid11, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
sns.scatterplot(data =eid12, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
sns.scatterplot(data =eid13, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
sns.scatterplot(data =eid14, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
sns.scatterplot(data =eid15, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
sns.scatterplot(data =eid16, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
sns.scatterplot(data =eid17, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
sns.scatterplot(data =eid18, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
sns.scatterplot(data =eid19, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
sns.scatterplot(data =eid10, x = "rho", y = "TE11_power", hue = "frequency", size = 0.001);

# %%
freqPower = sns.scatterplot(data = eid10, x = "frequency", y = "total_power", hue = "rho", size = 0.001)
freqPower.set_ylim(1e-13, 0.3  * 10 ** -12);

# %%
sns.scatterplot(data = eid10, x = "frequency", y = "TE11_power", hue = "rho",size = 0.001)
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='TE11_power'>

# %%
sns.scatterplot(data = eid10, x = "frequency", y = "rho", hue = "TE11_power", size = 0.001);

# %%
sns.scatterplot(data = eid11, x = "frequency", y = "rho", hue = "TE11_power", size = 0.001);

# %%
sns.scatterplot(data =eid15, x = "rho", y = "TE11_power", hue = "frequency", size = 0.001);

# %%
sns.scatterplot(data =eid19, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001);
