# %%
from astropy.table import QTable
import numpy as np
import matplotlib.pyplot as plt
import corner
import seaborn as sns
import pandas as pd

# %%
eid = pd.read_csv('./eid1/eid1_0.csv')
eid
# Out:
#         frequency  magnetic_field       rho   total_power    TE11_power
# 0    1.825039e+10             1.5  0.003174  1.730592e-13  4.778626e-15
# 1    1.901611e+10             1.5  0.001497  1.312043e-13  6.815139e-15
# 2    1.869109e+10             1.5  0.001854  1.493901e-13  6.547257e-15
# 3    1.824167e+10             1.5  0.002925  1.918128e-13  5.182244e-15
# 4    1.862265e+10             1.5  0.001676  1.407864e-13  6.795876e-15
# ..            ...             ...       ...           ...           ...
# 995  1.901649e+10             1.5  0.001250  1.341665e-13  7.056635e-15
# 996  1.840583e+10             1.5  0.001359  1.484642e-13  7.257021e-15
# 997  1.835082e+10             1.5  0.003298  1.620894e-13  4.542112e-15
# 998  1.829304e+10             1.5  0.003348  1.433352e-13  4.484284e-15
# 999  1.802930e+10             1.5  0.003378  1.466515e-13  4.539187e-15
#
# [1000 rows x 5 columns]

# %%
#x = eid['rho']
#y1 = eid['total_power']
#y2 = eid['TE11_power']

#fig, ax = plt.subplots(
#    figsize = (15 , 8),
#    constrained_layout = True
#)
sns.scatterplot(data =eid, x = "rho", y = "total_power", hue = "TE11_power", size = 0.001)
# Out:
# <AxesSubplot:xlabel='rho', ylabel='total_power'>

# %%
plt.scatter(x,y2)
ax.set_xlabel('Rho')
ax.set_ylabel('TE11 Power')
# Out:
# Text(0, 0.5, 'TE11 Power')
